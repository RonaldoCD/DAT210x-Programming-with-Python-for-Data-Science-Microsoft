# %% [markdown]
# # DAT210x - Programming with Python for DS

# %% [markdown]
# ## Module3 - Lab5

# %% [markdown]
# This code is intentionally missing! Read the directions on the course lab page!

# %%
# .. your code here ..

# %%
# %matplotlib notebook
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib
from sklearn.datasets import load_iris
from pandas.plotting import andrews_curves

# %%
df = pd.read_csv('Datasets/wheat.data')
df
# Out:
#       id   area  perimeter  compactness  length  width  asymmetry  groove  \
# 0      0  15.26      14.84       0.8710   5.763  3.312      2.221   5.220
# 1      1  14.88      14.57       0.8811   5.554  3.333      1.018   4.956
# 2      2  14.29      14.09       0.9050   5.291  3.337      2.699   4.825
# 3      3  13.84      13.94       0.8955   5.324  3.379      2.259   4.805
# 4      4  16.14      14.99       0.9034   5.658  3.562      1.355   5.175
# ..   ...    ...        ...          ...     ...    ...        ...     ...
# 205  205  12.19      13.20       0.8783   5.137  2.981      3.631   4.870
# 206  206  11.23      12.88       0.8511   5.140  2.795      4.325   5.003
# 207  207  13.20      13.66       0.8883   5.236  3.232      8.315   5.056
# 208  208  11.84      13.21       0.8521   5.175  2.836      3.598   5.044
# 209  209  12.30      13.34       0.8684   5.243  2.974      5.637   5.063
#
#     wheat_type
# 0         kama
# 1         kama
# 2         kama
# 3         kama
# 4         kama
# ..         ...
# 205   canadian
# 206   canadian
# 207   canadian
# 208   canadian
# 209   canadian
#
# [210 rows x 9 columns]

# %%
df2 = df.drop(['area', 'perimeter', 'id'], axis = 1)
df2
# Out:
#      compactness  length  width  asymmetry  groove wheat_type
# 0         0.8710   5.763  3.312      2.221   5.220       kama
# 1         0.8811   5.554  3.333      1.018   4.956       kama
# 2         0.9050   5.291  3.337      2.699   4.825       kama
# 3         0.8955   5.324  3.379      2.259   4.805       kama
# 4         0.9034   5.658  3.562      1.355   5.175       kama
# ..           ...     ...    ...        ...     ...        ...
# 205       0.8783   5.137  2.981      3.631   4.870   canadian
# 206       0.8511   5.140  2.795      4.325   5.003   canadian
# 207       0.8883   5.236  3.232      8.315   5.056   canadian
# 208       0.8521   5.175  2.836      3.598   5.044   canadian
# 209       0.8684   5.243  2.974      5.637   5.063   canadian
#
# [210 rows x 6 columns]

# %%
colorList=["r","b","g"]
plt.figure()
andrews_curves(df2, 'wheat_type', alpha = 0.2, color = colorList)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
df3 = df.drop('id', axis = 1)
df3
# Out:
#       area  perimeter  compactness  length  width  asymmetry  groove  \
# 0    15.26      14.84       0.8710   5.763  3.312      2.221   5.220
# 1    14.88      14.57       0.8811   5.554  3.333      1.018   4.956
# 2    14.29      14.09       0.9050   5.291  3.337      2.699   4.825
# 3    13.84      13.94       0.8955   5.324  3.379      2.259   4.805
# 4    16.14      14.99       0.9034   5.658  3.562      1.355   5.175
# ..     ...        ...          ...     ...    ...        ...     ...
# 205  12.19      13.20       0.8783   5.137  2.981      3.631   4.870
# 206  11.23      12.88       0.8511   5.140  2.795      4.325   5.003
# 207  13.20      13.66       0.8883   5.236  3.232      8.315   5.056
# 208  11.84      13.21       0.8521   5.175  2.836      3.598   5.044
# 209  12.30      13.34       0.8684   5.243  2.974      5.637   5.063
#
#     wheat_type
# 0         kama
# 1         kama
# 2         kama
# 3         kama
# 4         kama
# ..         ...
# 205   canadian
# 206   canadian
# 207   canadian
# 208   canadian
# 209   canadian
#
# [210 rows x 8 columns]

# %%
colorList=["r","b","g"]
plt.figure()
andrews_curves(df2, 'wheat_type', alpha = 0.2, color = colorList)
# Out:
# <img src="data:image/png;base64,..." width="640">
